# %%
50000
# Out:
# 50000

# %%
50000 - 15000
# Out:
# 35000

# %%
35000 + 8000
# Out:
# 43000

# %%
salary = 50000

# %%
salary
# Out:
# 50000

# %%
print(salary)
# Out:
# 50000

# %%
name = "Nora Jones"

print(name)
# Out:
# Nora Jones

# %%
age=26
print(age)
# Out:
# 26

# %% [markdown]
# ### ChatGPT
#
# - Show how you can paste in errors to ChatGPT and get responses

# %%
age = 25

Age = 35

AGE = 45

_age = 55

age_1 = 65

# %%
print("age: ", age)
print("Age: ", Age)
print("AGE: ", AGE)
print("_age: ", _age)
print("age_1: ", age_1)
# Out:
# age:  25
# Age:  35
# AGE:  45
# _age:  55
# age_1:  65

# %%
_age = 25

# %%
_age
# Out:
# 25

# %%
a = 88

b = 56

c = 101

# %%
print(a, b, c)
# Out:
# 88 56 101

# %% [markdown]
# Can reuse variables - new value will replace the old value in the variable

# %%
result_sum = a + b

result_sum
# Out:
# 144

# %%
result_sum = b + c

result_sum
# Out:
# 157

# %%
print(result_sum)
# Out:
# 157

# %%
income_tax = 5000

retirement_contribution = 1800

professional_tax = 300

salary = 50000

# %%
net_salary = salary - (income_tax + retirement_contribution + professional_tax)

print(net_salary)
# Out:
# 42900

# %% [markdown]
# ### Coding Practice
#
# - Initialize 3 variables with student's scores for math, english, science
# - Compute the total score and store it in a new variable
# - Print out the value of the total score
# - Compute the average score and store in a variable
# - Print out the value of the average score

# %%
math_score = 89

english_score = 75

science_score = 93

# %%
total_score = math_score + english_score + science_score
print("Total score: ", total_score)
# Out:
# Total score:  257

# %%
average_score = (math_score + english_score + science_score) / 3

print("Average score: ", average_score)
# Out:
# Average score:  85.66666666666667

# %%
first_name = "James"

last_name = "Bond"

# %%
first_name + last_name
# Out:
# 'JamesBond'

# %%
full_name = first_name + " " + last_name

full_name
# Out:
# 'James Bond'

# %%
salary_joe = salary_cara = salary_rob = 10000

# %%
salary_joe
# Out:
# 10000

# %%
salary_cara
# Out:
# 10000

# %%
salary_rob
# Out:
# 10000

# %%
salary_rob == salary_cara
# Out:
# True

# %%
salary_joe = salary_joe + 1000

salary_joe
# Out:
# 11000

# %%
salary_cara, salary_rob
# Out:
# (10000, 10000)

# %%
salary_cara = salary_cara * 1.12

salary_cara
# Out:
# 11200.000000000002

# %%
salary_joe, salary_rob
# Out:
# (11000, 10000)

# %%
salary_rob = salary_rob - salary_rob * 0.03

salary_rob
# Out:
# 9700.0

# %%
salary_rob == salary_cara
# Out:
# False

# %%
a = 5
b = a

a=a+5
print(b) 
print(a) # [1, 2, 3, 4]
# Out:
# 5
# 10

# %%
a = [1, 2, 3]
b = a

a.append(4)
print(b)  # [1, 2, 3, 4]
print(a)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %% [markdown]
# ### Coding Practice
#
# - Assign bank balances to Nancy, Derek, and Marlene
# - Bank balances should have the same value i.e. 5000
# - Nancy withdraws 100
# - Derek makes a deposit equal to 5% of his existing balance
# - Marlene withdraws 500 and then deposits 20% of the new balance (after 200 was withdrawn)
# - Show all of these operations in code and print out the resulting balances

# %%
balance_nancy = 5000
balance_derek = 5000
balance_marlene = 5000

# %%
balance_nancy = balance_nancy -100
balance_derek = balance_derek - balance_derek * 0.05
balance_marlene= ((balance_marlene - 500) *1.2) -200
print("Nancy's balance: ", balance_nancy)
print("Derek's balance: ", balance_derek)
print("Marlene's balance: ", balance_marlene)
# Out:
# Nancy's balance:  4900
# Derek's balance:  4750.0
# Marlene's balance:  5200.0

# %% [markdown]
# ### Data Types

# %%
score = 78

gpa = 3.7

is_active = True

name = "Charles"

# %%
print("Score: ", score)
print("GPA: ", gpa)
print("Is active: ", is_active)
print("Name: ", name)
# Out:
# Score:  78
# GPA:  3.7
# Is active:  True
# Name:  Charles

# %%
type(score)
# Out:
# int

# %%
type(gpa)
# Out:
# float

# %%
type(is_active)
# Out:
# bool

# %%
type(name)
# Out:
# str

# %%
result = score + gpa

print("The final result is: ", result)
# Out:
# The final result is:  81.7

# %%
result = score + is_active

print("The final result is: ", result)
# Out:
# The final result is:  79

# %%
result = score + False

print("The final result is: ", result)
# Out:
# The final result is:  78

# %%
result = score + name

print("The final result is: ", result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 result = score + name
#       3 print("The final result is: ", result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Multiple variable assignments

# %%
score, gpa, is_active, name = 52, 3.2, False, "Dora"

# %% [markdown]
# ### ChatGPT
#
# - Ask ChatGPT what this code does

# %%
print("Score: ", score)
print("GPA: ", gpa)
print("Is active: ", is_active)
print("Name: ", name)
# Out:
# Score:  52
# GPA:  3.2
# Is active:  False
# Name:  Dora

# %%
score, gpa, is_active, name = "Dora", False, 52, 3.2

# %%
print("Score: ", score)
print("GPA: ", gpa)
print("Is active: ", is_active)
print("Name: ", name)
# Out:
# Score:  Dora
# GPA:  False
# Is active:  52
# Name:  3.2

# %% [markdown]
# ### Assignment operators

# %%
number = 10

number
# Out:
# 10

# %%
number = number + 100

number
# Out:
# 110

# %%
number += 100

number
# Out:
# 210

# %%
number = number * 2

number
# Out:
# 420

# %%
number *= 2

number
# Out:
# 840

# %%
number = number / 3

number
# Out:
# 280.0

# %%
number //= 3

number
# Out:
# 90.0

# %%
number = number - 10

number
# Out:
# 80.0

# %%
number -= 10

number
# Out:
# 70.0

# %%
number = number // 5

number
# Out:
# 14.0

# %%
number //= 5

number
# Out:
# 2.0

# %%
number = 35

number = number % 6

number
# Out:
# 5

# %%
number = 33

number %= 6

number
# Out:
# 3

# %%
number = 3

number = number ** 4

number
# Out:
# 81

# %%
number = 3

number **= 4

number
# Out:
# 81

# %%
first_name
# Out:
# 'James'

# %%
salary_cara
# Out:
# 11200.000000000002

# %%
del first_name

first_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 3
#       1 del first_name
# ----> 3 first_name
#
# NameError: name 'first_name' is not defined

# %%
del salary_cara

salary_cara
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 3
#       1 del salary_cara
# ----> 3 salary_cara
#
# NameError: name 'salary_cara' is not defined

# %% [markdown]
# ### NoneType

# %%
variable = None

# %%
type(variable)
# Out:
# NoneType
